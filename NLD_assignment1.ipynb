# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def question233(t, z):
    N = z
    return [-2*N*np.log(0.1*N)]

sol = solve_ivp(question233, [0, 15], [26], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Cancerous tumor Growth curve')
sol = solve_ivp(question233, [0, 15], [5], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Cancerous tumor Growth curve')
sol = solve_ivp(question233, [0, 15], [3], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Cancerous tumor Growth curve')
sol = solve_ivp(question233, [0, 15], [20], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Cancerous tumor Growth curve')
sol = solve_ivp(question233, [0, 15], [1.5], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Cancerous tumor Growth curve')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
N,t = np.meshgrid(np.arange(0, 20, .5), np.arange(0, 10, .5))
N__dot = -2*N*np.log(0.1*N)
u = N*(1/((N__dot**2 +1)**0.5))
v = N*(N__dot/((N__dot**2 +1)**0.5))
fig, ax = plt.subplots(1 ,figsize=(10, 6), dpi=80)
q = ax.quiver(t,N,u,v, edgecolor='k', width = 0.003)
ax.set_title('Tumor Growth vector field')
# Out:
# C:\Users\Baibhab Mustafi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# C:\Users\Baibhab Mustafi\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: invalid value encountered in multiply
#   after removing the cwd from sys.path.
# Text(0.5, 1.0, 'Tumor Growth vector field')

# %%
import matplotlib.pyplot as plt
import numpy as np

N = np.linspace(0,10 , 256, endpoint=True)
N__dot = -2*N*np.log(0.1*N)
plt.plot(N, N__dot)
ax = plt.gca() 
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.title('tumor growth N_dot vs N')

plt.show()
# Out:
# C:\Users\Baibhab Mustafi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: divide by zero encountered in log
#   """
# C:\Users\Baibhab Mustafi\Anaconda3\lib\site-packages\ipykernel_launcher.py:5: RuntimeWarning: invalid value encountered in multiply
#   """

# %%
import matplotlib.pyplot as plt
import numpy as np
N = np.linspace(-30,10 , 256, endpoint=True)
N_dotbyN = 500-15*((N+15)**2)
plt.plot(N, N_dotbyN)
ax = plt.gca() 
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))
plt.title('N_dotbyN Vs N')
plt.show()

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def question234(t, z):
    N = z
    return [N*(500-15*((N+15)**2))]

sol = solve_ivp(question234, [0, 15], [10], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
sol = solve_ivp(question234, [0, 15], [24], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')

sol = solve_ivp(question234, [0, 15], [-24], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
sol = solve_ivp(question234, [0, 15], [-4], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
plt.show()

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def question234(t, z):
    N = z
    return [(500-15*((N+15)**2))]

sol = solve_ivp(question234, [0, 100], [10], method='RK45', dense_output=True)

t = np.linspace(0, 100, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
sol = solve_ivp(question234, [0, 100], [24], method='RK45', dense_output=True)

t = np.linspace(0, 100, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')

sol = solve_ivp(question234, [0, 100], [-24], method='RK45', dense_output=True)

t = np.linspace(0, 100, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
sol = solve_ivp(question234, [0, 100], [-4], method='RK45', dense_output=True)

t = np.linspace(0, 100, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect 2.3.4')
plt.show()

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def question234(t, z):
    x = z
    return [ - x**3]

sol = solve_ivp(question234, [0, 15], [10], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect')
def question234(t, z):
    x = z
    return [-3*x - x**3]

sol = solve_ivp(question234, [0, 15], [10], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect')
def question234(t, z):
    x = z
    return [+3*x - x**3]

sol = solve_ivp(question234, [0, 15], [10], method='RK45', dense_output=True)
t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['N'], shadow=True)
plt.title('Alle effect')

plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
plt.figure(figsize=(10, 6), dpi=80)
X = np.linspace(-10,10 , 256, endpoint=True)
X__dot = -9*X - X**3
X__dot1 = -X**3
X__dot2 = +25*X - X**3
plt.plot(X, X__dot)
plt.plot(X, X__dot1)
plt.plot(X, X__dot2)
ax = plt.gca() 
ax.spines['top'].set_color('none')
ax.xaxis.set_ticks_position('bottom')
ax.spines['bottom'].set_position(('data',0))
ax.yaxis.set_ticks_position('left')
ax.spines['left'].set_position(('data',0))

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
def question249(t, z):
    x = z
    return [-x**3]
sol = solve_ivp(question249, [0, 100], [15], method='RK45', dense_output=True)

t = np.linspace(0, 100, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['x'], shadow=True)
plt.title('Critical slowing down')
plt.show()

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt
def question249(t, z):
    x = z
    return [-x**3]
sol = solve_ivp(question249, [0, 10], [10], method='RK45', dense_output=True)

t = np.linspace(0, 10, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['x'], shadow=True)
plt.title('Critical slowing down')
def question249a(t, z):
    x = z
    return [-x]
sol = solve_ivp(question249a, [0, 10], [10], method='RK45', dense_output=True)
t = np.linspace(0, 10, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['x'], shadow=True)

plt.show()

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

def question286(t, z):
    x = z
    return [x + np.exp(-x)]

sol = solve_ivp(question286, [0, 15], [0], method='RK45', dense_output=True)

t = np.linspace(0, 15, 300)
z = sol.sol(t)
plt.plot(t, z.T)
plt.xlabel('t')
plt.legend(['x'], shadow=True)
plt.title('2.8.6 analytically intractible problem')
# Out:
# Text(0.5, 1.0, '2.8.6 analytically intractible problem')

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

a =0
y = 0
N = 1
P= [0]
Z = [0]
for i in range(0,2500):
    y = y + 0.01*N
    N = y + np.exp(-y)
    Z.append(N)
    a = a + 0.01
    P.append(a)
plt.plot(P,Z, color = "red")

b=0 
n=0
F = 1
p = [0]
k = [0]
for j in range(0,256):
    n = n + 0.1*F
    F = n + np.exp(-n)
    k.append(F)
    b = b + 0.1
    p.append(b)
plt.plot(p,k, color = "green")
c = 0
d = 0
M = 1
L = [0]
O = [0]
for j in range(0,35):
    c= c + 1*M
    M = c + np.exp(-c)
    L.append(M)
    d = d + 1
    O.append(d)
plt.plot(O,L, color = "black")

def question286(t, z):
    x = z
    return [x + np.exp(-x)]

sol = solve_ivp(question286, [0, 20], [0], method='RK45', dense_output=True)

t = np.linspace(0, 27, 300)
z = sol.sol(t)
plt.plot(t, z.T, color = "blue")
plt.xlabel('t')
plt.legend(['x'], shadow=True)
plt.title('2.8.6 analytically intractible problem')
# Out:
# Text(0.5, 1.0, '2.8.6 analytically intractible problem')

# %%
import numpy as np
import scipy as sp
from scipy.integrate import solve_ivp
import matplotlib.pyplot as plt

a =0
y = 0
N = 1
P= [0]
Z = [0]
for i in range(0,2500):
    y = y + 0.01*N
    N = y + np.exp(-y)
    Z.append(N)
    a = a + 0.01
    P.append(a)
plt.plot(P,Z, color = "red")
plt.show()
